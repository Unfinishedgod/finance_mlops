# %%
import plotly.graph_objects as go

from ta.trend import MACD
from ta.momentum import StochasticOscillator

import numpy as np
import pandas as pd
from pykrx import stock
from pykrx import bond
from time import sleep

from datetime import datetime
from datetime import timedelta
import os
import time
from plotly.subplots import make_subplots
import glob

# %%
os.chdir('/home/shjj08choi4/finance_mlops')

# %%
df = pd.read_csv('data_crawler/ohlcv_df_raw.csv')

# %%
df[df['date'] < '2023-11-01']
# Out:
#               date   open   high    low  close  volume  \
# 0       2018-01-02  51380  51400  50780  51020  169485
# 1       2018-01-03  52540  52560  51420  51620  200270
# 2       2018-01-04  52120  52180  50640  51080  233909
# 3       2018-01-05  51300  52120  51200  52120  189623
# 4       2018-01-08  52400  52520  51500  52020  167673
# ...            ...    ...    ...    ...    ...     ...
# 133701  2023-10-25  10270  10420  10100  10310  202518
# 133702  2023-10-26  10100  10130   9800   9820  406661
# 133703  2023-10-27   9900   9970   9640   9690  283074
# 133704  2023-10-30   9640   9930   9630   9810  200570
# 133705  2023-10-31   9880  10060   9570   9640  331463
#
#         price_change_percentage  ticker corp_name     market
# 0                      0.117739    5930      삼성전자  KOSPI_100
# 1                      1.176009    5930      삼성전자  KOSPI_100
# 2                     -1.046106    5930      삼성전자  KOSPI_100
# 3                      2.036022    5930      삼성전자  KOSPI_100
# 4                     -0.191865    5930      삼성전자  KOSPI_100
# ...                         ...     ...       ...        ...
# 133701                 0.291829  137310  에스디바이오센서  KOSPI_100
# 133702                -4.752667  137310  에스디바이오센서  KOSPI_100
# 133703                -1.323829  137310  에스디바이오센서  KOSPI_100
# 133704                 1.238390  137310  에스디바이오센서  KOSPI_100
# 133705                -1.732926  137310  에스디바이오센서  KOSPI_100
#
# [133112 rows x 10 columns]
