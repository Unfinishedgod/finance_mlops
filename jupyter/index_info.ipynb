# %%
import pandas as pd
from pykrx import stock
from pykrx import bond
from time import sleep

from datetime import datetime
import os
import time

import glob


# 경로 변경
os.chdir('/home/shjj08choi/finance_mlops')

# %%
kor_index_list_df = pd.read_csv('data_crawler/kor_index_list_df/kor_index_list_df_20230825.csv')

# %%
index_code_master = pd.read_csv('data_crawler/index_code_master/index_code_master_20230825.csv', dtype = {'ticker': object})

# %%
kor_index_ohlcv = pd.read_csv('data_crawler/kor_index_ohlcv/kor_index_ohlcv_20230825.csv', dtype = {'ticker': object})

# %%
index_code_master
# Out:
#        ticker  index_code      index_code_nm  market corp_name
# 0      005930        1001                코스피   KOSPI      삼성전자
# 1      373220        1001                코스피   KOSPI  LG에너지솔루션
# 2      000660        1001                코스피   KOSPI    SK하이닉스
# 3      207940        1001                코스피   KOSPI  삼성바이오로직스
# 4      005490        1001                코스피   KOSPI  POSCO홀딩스
# ...       ...         ...                ...     ...       ...
# 13528  225570        2218  코스닥 150 커뮤니케이션서비스  KOSDAQ     넥슨게임즈
# 13529  067160        2218  코스닥 150 커뮤니케이션서비스  KOSDAQ    아프리카TV
# 13530  078340        2218  코스닥 150 커뮤니케이션서비스  KOSDAQ       컴투스
# 13531  119860        2218  코스닥 150 커뮤니케이션서비스  KOSDAQ    커넥트웨이브
# 13532  299900        2218  코스닥 150 커뮤니케이션서비스  KOSDAQ   위지윅스튜디오
#
# [13533 rows x 5 columns]

# %%
kor_index_ohlcv[kor_index_ohlcv['date'] > '2023-01-01']
# Out:
#               date     open     high      low    close     volume  \
# 1248    2023-01-26  2436.18  2468.65  2426.40  2468.65  486831888
# 1249    2023-01-27  2474.52  2497.40  2464.53  2484.02  509288123
# 1250    2023-01-30  2484.64  2491.13  2446.59  2450.47  475410252
# 1251    2023-01-31  2449.92  2457.48  2423.37  2425.08  617195639
# 1252    2023-02-01  2446.03  2453.29  2433.37  2449.80  666296326
# ...            ...      ...      ...      ...      ...        ...
# 134011  2023-08-21  2839.67  2856.25  2791.74  2794.01    3558831
# 134012  2023-08-22  2801.79  2820.50  2781.86  2795.58    3189192
# 134013  2023-08-23  2800.19  2810.70  2729.68  2734.42    5143980
# 134014  2023-08-24  2760.93  2780.64  2740.08  2760.04    3462347
# 134015  2023-08-25  2730.54  2774.03  2714.73  2743.58    2652407
#
#          trading_value        market_cap  index_code  close_2
# 1248     8206398683439  1953918425527295        1001  2468.65
# 1249     9092446576759  1966558578500389        1001  2484.02
# 1250     9220413382464  1940151030295828        1001  2450.47
# 1251    10394784014909  1918934214743307        1001  2425.08
# 1252     8596020942471  1938780673481178        1001   2449.8
# ...                ...               ...         ...      ...
# 134011    187023003660    21857810315930        2218  2794.01
# 134012    171057095440    21888327695220        2218  2795.58
# 134013    250349340860    21332623929290        2218  2734.42
# 134014    157476015815    21536697255290        2218  2760.04
# 134015    128819166075    21411017678170        2218  2743.58
#
# [14162 rows x 10 columns]

# %%
index_code_master[index_code_master['index_code'] == 1008]
# Out:
#       ticker  index_code index_code_nm market corp_name
# 1729  051910        1008            화학  KOSPI      LG화학
# 1730  096770        1008            화학  KOSPI   SK이노베이션
# 1731  010950        1008            화학  KOSPI     S-Oil
# 1732  090430        1008            화학  KOSPI    아모레퍼시픽
# 1733  001570        1008            화학  KOSPI        금양
# ...      ...         ...           ...    ...       ...
# 1827  006380        1008            화학  KOSPI       카프로
# 1828  051630        1008            화학  KOSPI      진양화학
# 1829  024070        1008            화학  KOSPI    WISCOM
# 1830  010640        1008            화학  KOSPI      진양폴리
# 1831  025620        1008            화학  KOSPI   제이준코스메틱
#
# [103 rows x 5 columns]

# %%
df[df['market'] == 'KOSDAQ']
# df[df['market'] == 'KOSPI']
#'1001', '2001'
# Out:
#     index_code      index_code_nm  market
# 46        2001                코스닥  KOSDAQ
# 47        2002            코스닥 대형주  KOSDAQ
# 48        2003            코스닥 중형주  KOSDAQ
# 49        2004            코스닥 소형주  KOSDAQ
# 50        2012              기타서비스  KOSDAQ
# 51        2015             코스닥 IT  KOSDAQ
# 52        2024                제조업  KOSDAQ
# 53        2026                 건설  KOSDAQ
# 54        2027                 유통  KOSDAQ
# 55        2029                 운송  KOSDAQ
# 56        2031                 금융  KOSDAQ
# 57        2037              오락·문화  KOSDAQ
# 58        2041            통신방송서비스  KOSDAQ
# 59        2042       IT S/W & SVC  KOSDAQ
# 60        2043             IT H/W  KOSDAQ
# 61        2056             음식료·담배  KOSDAQ
# 62        2058              섬유·의류  KOSDAQ
# 63        2062              종이·목재  KOSDAQ
# 64        2063            출판·매체복제  KOSDAQ
# 65        2065                 화학  KOSDAQ
# 66        2066                 제약  KOSDAQ
# 67        2067                비금속  KOSDAQ
# 68        2068                 금속  KOSDAQ
# 69        2070              기계·장비  KOSDAQ
# 70        2072             일반전기전자  KOSDAQ
# 71        2074            의료·정밀기기  KOSDAQ
# 72        2075            운송장비·부품  KOSDAQ
# 73        2077               기타제조  KOSDAQ
# 74        2151              통신서비스  KOSDAQ
# 75        2152              방송서비스  KOSDAQ
# 76        2153                인터넷  KOSDAQ
# 77        2154             디지털컨텐츠  KOSDAQ
# 78        2155              소프트웨어  KOSDAQ
# 79        2156             컴퓨터서비스  KOSDAQ
# 80        2157               통신장비  KOSDAQ
# 81        2158               정보기기  KOSDAQ
# 82        2159                반도체  KOSDAQ
# 83        2160               IT부품  KOSDAQ
# 84        2181          코스닥 우량기업부  KOSDAQ
# 85        2182          코스닥 벤처기업부  KOSDAQ
# 86        2183          코스닥 중견기업부  KOSDAQ
# 87        2184        코스닥 기술성장기업부  KOSDAQ
# 88        2189            코스닥 글로벌  KOSDAQ
# 89        2203            코스닥 150  KOSDAQ
# 90        2212         코스닥 150 소재  KOSDAQ
# 91        2213        코스닥 150 산업재  KOSDAQ
# 92        2214      코스닥 150 필수소비재  KOSDAQ
# 93        2215      코스닥 150 자유소비재  KOSDAQ
# 94        2216       코스닥 150 정보기술  KOSDAQ
# 95        2217       코스닥 150 헬스케어  KOSDAQ
# 96        2218  코스닥 150 커뮤니케이션서비스  KOSDAQ

# %%
import random
df = pd.DataFrame(
    {
        "name": ["Roadmap", "Extras", "Issues"],
        "url": ["https://roadmap.streamlit.app", "https://extras.streamlit.app", "https://issues.streamlit.app"],
        "stars": [random.randint(0, 1000) for _ in range(3)],
        "views_history": [[random.randint(0, 5000) for _ in range(30)] for _ in range(3)],
    }
)

# %%
df['views_history'][0][10]
# Out:
# 2605

# %%
kor_index_ohlcv
# Out:
#               date     open     high      low    close     volume  \
# 0       2018-01-02  2474.86  2481.02  2465.94  2479.65  262205431
# 1       2018-01-03  2484.63  2493.40  2481.91  2486.35  331094681
# 2       2018-01-04  2502.50  2502.50  2466.45  2466.46  333836328
# 3       2018-01-05  2476.85  2497.52  2475.51  2497.52  308769669
# 4       2018-01-08  2510.70  2515.37  2494.18  2513.28  311429324
# ...            ...      ...      ...      ...      ...        ...
# 134011  2023-08-21  2839.67  2856.25  2791.74  2794.01    3558831
# 134012  2023-08-22  2801.79  2820.50  2781.86  2795.58    3189192
# 134013  2023-08-23  2800.19  2810.70  2729.68  2734.42    5143980
# 134014  2023-08-24  2760.93  2780.64  2740.08  2760.04    3462347
# 134015  2023-08-25  2730.54  2774.03  2714.73  2743.58    2652407
#
#         trading_value        market_cap  index_code  close_2
# 0       4786386686165  1613508196692261        1001  2479.65
# 1       6019622040484  1617634317727445        1001  2486.35
# 2       6896287056563  1604916139690676        1001  2466.46
# 3       6317518427311  1624970533116195        1001  2497.52
# 4       6404885697956  1634777680824259        1001  2513.28
# ...               ...               ...         ...      ...
# 134011   187023003660    21857810315930        2218  2794.01
# 134012   171057095440    21888327695220        2218  2795.58
# 134013   250349340860    21332623929290        2218  2734.42
# 134014   157476015815    21536697255290        2218  2760.04
# 134015   128819166075    21411017678170        2218  2743.58
#
# [134016 rows x 10 columns]

# %%
kor_index_ohlcv['close_2'] = kor_index_ohlcv['close'].astype(str)

# %%
kor_index_ohlcv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134016 entries, 0 to 134015
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   date           134016 non-null  object
#  1   open           134016 non-null  float64
#  2   high           134016 non-null  float64
#  3   low            134016 non-null  float64
#  4   close          134016 non-null  float64
#  5   volume         134016 non-null  int64
#  6   trading_value  134016 non-null  int64
#  7   market_cap     134016 non-null  int64
#  8   index_code     134016 non-null  int64
#  9   close_2        134016 non-null  object
# dtypes: float64(4), int64(4), object(2)
# memory usage: 10.2+ MB

# %%
df11 = kor_index_ohlcv.groupby(['index_code'])['close'].apply(list).reset_index()

# %%
df2 = pd.merge(kor_index_list_df, df11, 
        on = 'index_code', 
        how = 'left')

# %%
df2
# Out:
#     index_code      index_code_nm  market  \
# 0         1001                코스피   KOSPI
# 1         1002            코스피 대형주   KOSPI
# 2         1003            코스피 중형주   KOSPI
# 3         1004            코스피 소형주   KOSPI
# 4         1005               음식료품   KOSPI
# ..         ...                ...     ...
# 92        2214      코스닥 150 필수소비재  KOSDAQ
# 93        2215      코스닥 150 자유소비재  KOSDAQ
# 94        2216       코스닥 150 정보기술  KOSDAQ
# 95        2217       코스닥 150 헬스케어  KOSDAQ
# 96        2218  코스닥 150 커뮤니케이션서비스  KOSDAQ
#
#                                                 close
# 0   [2479.65, 2486.35, 2466.46, 2497.52, 2513.28, ...
# 1   [2426.84, 2435.35, 2416.98, 2450.08, 2468.55, ...
# 2   [2757.97, 2756.65, 2721.55, 2746.19, 2755.17, ...
# 3   [2056.72, 2071.01, 2060.95, 2087.55, 2087.61, ...
# 4   [4412.39, 4420.45, 4392.61, 4371.83, 4343.04, ...
# ..                                                ...
# 92  [1043.78, 1017.44, 979.36, 999.0, 987.28, 968....
# 93  [1197.08, 1180.11, 1167.09, 1193.62, 1187.8, 1...
# 94  [758.41, 757.5, 730.79, 737.05, 720.3, 712.25,...
# 95  [4854.79, 4958.23, 4784.35, 5015.39, 5213.73, ...
# 96  [2234.02, 2183.46, 2128.01, 2145.34, 2108.99, ...
#
# [97 rows x 4 columns]

# %%
df2['index_code_nm']
# Out:
# 0                   코스피
# 1               코스피 대형주
# 2               코스피 중형주
# 3               코스피 소형주
# 4                  음식료품
#             ...
# 92        코스닥 150 필수소비재
# 93        코스닥 150 자유소비재
# 94         코스닥 150 정보기술
# 95         코스닥 150 헬스케어
# 96    코스닥 150 커뮤니케이션서비스
# Name: index_code_nm, Length: 97, dtype: object

# %%
kor_index_ohlcv[kor_index_ohlcv['index_code'] == 1001]['close']
# Out:
# 0       2479.65
# 1       2486.35
# 2       2466.46
# 3       2497.52
# 4       2513.28
#          ...
# 1389    2508.80
# 1390    2515.74
# 1391    2505.50
# 1392    2537.68
# 1393    2519.14
# Name: close, Length: 1394, dtype: float64
